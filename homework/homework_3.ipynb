# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <b>Dataset</b>

# %%
data = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv"
df = pd.read_csv(data)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# <b>Features</b>

# %%
features = ['Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 
            'Vehicle Style', 'highway MPG', 'city mpg', 'MSRP']

# %% [markdown]
# <b>Data preparation</b>

# %%
df = df[features]
df.columns = df.columns.str.replace(' ', '_').str.lower()
categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
for column in categorical_columns:
    df[column] = df[column].str.replace(' ', '_').str.lower()
df
# Out:
# C:\Users\CrackedStone\AppData\Local\Temp\ipykernel_17884\2627464424.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.replace(' ', '_').str.lower()
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# ...

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# msrp                 0
# dtype: int64

# %%
df['price'] = df['msrp']
del df['msrp']
df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# 11910    acura         zdx  2012      300.0               6.0
# 11911    acura         zdx  2012      300.0               6.0
# 11912    acura         zdx  2013      300.0               6.0
# 11913  lincoln      zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price
# 0                manual          coupe           26        19  46135
# 1                manual    convertible           28        19  40650
# ...

# %% [markdown]
# <b>Question 1</b>

# %%
df.transmission_type.value_counts()
# Out:
# transmission_type
# automatic           8266
# manual              2935
# automated_manual     626
# direct_drive          68
# unknown               19
# Name: count, dtype: int64

# %% [markdown]
# <b>Question 2</b>

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg']
categorical = ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
for variable in numerical:
    print(variable)
    print(df[numerical].corrwith(df[variable]))
    print()
# Out:
# year
# year                1.000000
# engine_hp           0.338714
# engine_cylinders   -0.040708
# highway_mpg         0.258240
# city_mpg            0.198171
# dtype: float64
#
# engine_hp
# year                0.338714
# engine_hp           1.000000
# engine_cylinders    0.774851
# highway_mpg        -0.415707
# city_mpg           -0.424918
# dtype: float64
#
# engine_cylinders
# year               -0.040708
# engine_hp           0.774851
# engine_cylinders    1.000000
# highway_mpg        -0.614541
# city_mpg           -0.587306
# dtype: float64
#
# highway_mpg
# year                0.258240
# engine_hp          -0.415707
# engine_cylinders   -0.614541
# highway_mpg         1.000000
# city_mpg            0.886829
# dtype: float64
#
# city_mpg
# year                0.198171
# engine_hp          -0.424918
# engine_cylinders   -0.587306
# highway_mpg         0.886829
# city_mpg            1.000000
# dtype: float64

# %% [markdown]
# <b>Making "price" binary</b>

# %%
mean_price = df.price.mean()
mean_price
# Out:
# 40594.737032063116

# %%
df['above_average'] = (df.price > mean_price).astype(int)
price = df['price']
df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# 11910    acura         zdx  2012      300.0               6.0
# 11911    acura         zdx  2012      300.0               6.0
# 11912    acura         zdx  2013      300.0               6.0
# 11913  lincoln      zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price  \
# 0                manual          coupe           26        19  46135
# 1                manual    convertible           28        19  40650
# ...

# %% [markdown]
# <b>Splitting the data</b>

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25)
len(df_train), len(df_val), len(df_test)
# Out:
# (7148, 2383, 2383)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train['above_average']
y_val = df_val['above_average']
y_test = df_test['above_average']
y_train_price = np.log1p(df_train['price'].values)
y_val_price = np.log1p(df_val['price'].values)
y_test_price = np.log1p(df_test['price'].values)

# %%
del df_train['above_average']
del df_val['above_average']
del df_test['above_average']

del df_train['price']
del df_val['price']
del df_test['price']

# %% [markdown]
# <b>Question 3</b>

# %%
from sklearn.metrics import mutual_info_score

# %%
def mutual_info_above_average_score(series):
    return mutual_info_score(series, y_train)

# %%
mutual_info = df_train[categorical].apply(mutual_info_above_average_score)
mutual_info.sort_values(ascending=True).to_frame('Mutual Information')
# Out:
#                    Mutual Information
# transmission_type            0.021530
# vehicle_style                0.086276
# make                         0.240350
# model                        0.461245

# %% [markdown]
# <b>Question 4</b>

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
val_dicts = df_val[categorical + numerical].to_dict(orient='records')
dv = DictVectorizer(sparse=False)

# %%
X_train = dv.fit_transform(train_dicts)
X_val = dv.transform(val_dicts)

# %%
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_val)
accuracy = (y_pred == y_val).mean()
round(accuracy, 2)
# Out:
# 0.95

# %% [markdown]
# <b>Question 5</b>

# %%
features_to_eliminiate = ['transmission_type', 'year', 'engine_hp', 'city_mpg']

for feature in features_to_eliminiate:
    categorical = ['make', 'model', 'transmission_type', 'vehicle_style'] 
    numerical = ['year', 'engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg'] 
    features = categorical + numerical
    
    features.remove(feature)
    
    train_dicts = df_train[features].to_dict(orient='records')
    val_dicts = df_val[features].to_dict(orient='records')
    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(train_dicts)
    X_val = dv.transform(val_dicts)

    model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    accuracy_difference = accuracy - (y_pred == y_val).mean()
    
    print(feature, accuracy_difference)
# Out:
# transmission_type -0.0012589173310951773
# year -0.0020981955518253326
# engine_hp 0.01091061686949224
# city_mpg 0.00461603021401602

# %% [markdown]
# <b>Question 6</b>

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
alpha_values = [0, 0.01, 0.1, 1, 10]

# %%
for value in alpha_values:
    train_dicts = df_train[categorical + numerical].to_dict(orient='records')
    val_dicts = df_val[categorical + numerical].to_dict(orient='records')
    dv = DictVectorizer(sparse=True)
    
    X_train = dv.fit_transform(train_dicts)
    X_val = dv.transform(val_dicts)
    
    model = Ridge(alpha=value, solver='sag', random_state=42)
    model.fit(X_train, y_train_price)
    y_pred = model.predict(X_val)
    
    score = mean_squared_error(y_val_price, y_pred)
    print(f'For alpha = {value} the score is {round(score, 3)}')
# Out:
# For alpha = 0 the score is 0.078
# For alpha = 0.01 the score is 0.078
# For alpha = 0.1 the score is 0.075
# For alpha = 1 the score is 0.078
# For alpha = 10 the score is 0.119
